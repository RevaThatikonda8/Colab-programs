# %% [markdown]
# <a href="https://colab.research.google.com/github/RevaThatikonda8/Colab-programs/blob/main/SE_TASK__.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#hardcoding varaibles
a=10
b=20
result=a+b
print(f"hardcoded Addition: {a}+{b}={result}")
# Out:
# hardcoded Addition: 10+20=30

# %%
5#Keyboard Input
try:
  x=int(input("Enter the first number:"))
  y=int(input ("Enter the second number:"))
  result=x+y
  print(f"User Input Addition {x}  + {y} = {result}")
except ValueError:
  print("Please enter valid integer! ")
# Out:
# Enter the first number:5
# Enter the second number:5
# User Input Addition 5  + 5 = 10

# %%
#Read From File (Single Input)
# Save the file in the runtime (for demonstration)
with open("single_input.txt", "w") as f:
    f.write("42")
# Reading single input from a file
try:
    with open("single_input.txt", "r") as f:
        num = int(f.read().strip())
        result = num * 2
        print(f"Single Input Read from File: {num} * 2 = {result}")
except FileNotFoundError:
    print("File not found!")
except ValueError:
    print("Error in reading or converting the input!")
# Out:
# Single Input Read from File: 42 * 2 = 84

# %%
#Read From File (Single Input)
# Save the file in the runtime (for demonstration)
with open("single_input.txt", "w") as f:
    f.write("42")
# Reading single input from a file
try:
    with open("single_input.txt", "r") as f:
        num = int(f.read().strip())
        result = num * 2
        print(f"Single Input Read from File: {num} * 2 = {result}")
except FileNotFoundError:
    print("File not found!")
except ValueError:
    print("Error in reading or converting the input!")
# Out:
# Single Input Read from File: 42 * 2 = 84
